# %%
import json

with open("logs.json", "w") as f:
    json.dump([], f)

print("logs.json created successfully")
# Out:
# logs.json created successfully

# %%
with open("logs.json", "r") as f:
    print(f.read())
# Out:
# []
